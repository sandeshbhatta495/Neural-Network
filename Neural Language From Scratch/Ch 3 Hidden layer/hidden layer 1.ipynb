# %%
import numpy as np

# %%
inputs = [[1, 2, 3, 2.5],
          [2., 5., -1., 2],
          [-1.5, 2.7, 3.3, -0.8]]
weights1 = [[0.2, 0.8, -0.5, 1],
            [0.5, -0.91, 0.26, -0.5],
            [-0.26, -0.27, 0.17, 0.87]]
biases1 = [2, 3, 0.5]

weights2 = [[0.1, -0.14, 0.5],
            [-0.5, 0.12, -0.33],
            [-0.44, 0.73, -0.13]]
biases2 = [-1, 2, -0.5]

# %%
# output layer of 1 
out1 = np.dot(inputs,np.array(weights1).T) + biases1

# %%
out1
# Out:
# array([[ 4.8  ,  1.21 ,  2.385],
#        [ 8.9  , -1.81 ,  0.2  ],
#        [ 1.41 ,  1.051,  0.026]])

# %%
# for out2 
out2 = np.dot(o,np.array(weights2).T) + biases2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # for out2
# ----> 2 out2 = np.dot(inputs,np.array(weights2).T) + biases2
#
# ValueError: shapes (3,4) and (3,3) not aligned: 4 (dim 1) != 3 (dim 0)
